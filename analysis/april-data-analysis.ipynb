# %% [markdown]
# # April Mess Breakfast Data — Analysis
#
# Source: `data/april-data-clean.csv` (cleaned from `april-data.xlsx` by `scripts/clean_april_data.py`).
#
# Each row is one registered Kadamba mess breakfast slot for April 2026. `availed_at` is blank when the slot was registered but never swiped in.

# %%
import pandas as pd

df = pd.read_csv(
    "../data/april-data-clean.csv",
    parse_dates=["meal_date", "availed_at"],
)
df.shape
# Out:
# (32162, 8)

# %%
df.head()
# Out:
#    meal_date       meal_mess                       availed_at  availed  \
# 0 2026-04-01  kadamba-nonveg 2026-04-01 07:29:38.668183+05:30     True
# 1 2026-04-01  kadamba-nonveg 2026-04-01 07:34:28.989089+05:30     True
# 2 2026-04-01  kadamba-nonveg 2026-04-01 07:34:55.971712+05:30     True
# 3 2026-04-01  kadamba-nonveg 2026-04-01 07:36:19.314233+05:30     True
# 4 2026-04-01  kadamba-nonveg 2026-04-01 07:36:58.922198+05:30     True
#
#   day_of_week  is_weekend availed_time_ist  availed_hour_ist
# 0   Wednesday       False  07:29:38.668183               7.0
# 1   Wednesday       False  07:34:28.989089               7.0
# 2   Wednesday       False  07:34:55.971712               7.0
# 3   Wednesday       False  07:36:19.314233               7.0
# 4   Wednesday       False  07:36:58.922198               7.0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32162 entries, 0 to 32161
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   meal_date         32162 non-null  datetime64[us]
#  1   meal_mess         32162 non-null  str
#  2   availed_at        11941 non-null  datetime64[us, UTC+05:30]
#  3   availed           32162 non-null  bool
#  4   day_of_week       32162 non-null  str
#  5   is_weekend        32162 non-null  bool
#  6   availed_time_ist  11941 non-null  str
#  7   availed_hour_ist  11941 non-null  float64
# dtypes: bool(2), datetime64[us, UTC+05:30](1), datetime64[us](1), float64(1), str(3)
# memory usage: 2.3 MB

# %%
df.describe(include="all")
# Out:
#                          meal_date    meal_mess  \
# count                        32162        32162
# unique                         NaN            2
# top                            NaN  kadamba-veg
# freq                           NaN        22715
# mean    2026-04-15 16:28:03.477395          NaN
# min            2026-04-01 00:00:00          NaN
# 25%            2026-04-08 00:00:00          NaN
# 50%            2026-04-16 00:00:00          NaN
# 75%            2026-04-23 00:00:00          NaN
# max            2026-04-30 00:00:00          NaN
# std                            NaN          NaN
#
#                               availed_at availed day_of_week is_weekend  \
# count                              11941   32162       32162      32162
# unique                               NaN       2           7          2
# top                                  NaN   False    Thursday      False
# freq                                 NaN   20221        5380      23605
# ...

# %%
df.isna().sum()
# Out:
# meal_date               0
# meal_mess               0
# availed_at          20221
# availed                 0
# day_of_week             0
# is_weekend              0
# availed_time_ist    20221
# availed_hour_ist    20221
# dtype: int64
